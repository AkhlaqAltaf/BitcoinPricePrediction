# %%
# !kaggle datasets download -d akhlaqaltaf/task-1
# Out:
# Dataset URL: https://www.kaggle.com/datasets/akhlaqaltaf/task-1
# License(s): unknown
# ...
#   0%|          | 0.00/100M [00:00<?, ?B/s]
#   1%|          | 1.00M/100M [00:01<02:11, 795kB/s]
#   2%|▏         | 2.00M/100M [00:01<01:08, 1.50MB/s]
#   4%|▍         | 4.00M/100M [00:01<00:29, 3.45MB/s]
#   6%|▌         | 6.00M/100M [00:01<00:19, 5.19MB/s]
#   8%|▊         | 8.00M/100M [00:02<00:14, 6.69MB/s]
#  10%|▉         | 10.0M/100M [00:02<00:11, 8.02MB/s]
#  12%|█▏        | 12.0M/100M [00:02<00:10, 8.91MB/s]
#  14%|█▍        | 14.0M/100M [00:02<00:09, 9.68MB/s]
#  16%|█▌        | 16.0M/100M [00:02<00:08, 10.2MB/s]
#  18%|█▊        | 18.0M/100M [00:02<00:08, 10.7MB/s]
#  20%|█▉        | 20.0M/100M [00:03<00:07, 11.0MB/s]
#  22%|██▏       | 22.0M/100M [00:03<00:07, 11.2MB/s]
#  24%|██▍       | 24.0M/100M [00:03<00:06, 11.5MB/s]
#  26%|██▌       | 26.0M/100M [00:03<00:06, 11.4MB/s]
#  28%|██▊       | 28.0M/100M [00:03<00:06, 11.6MB/s]
#  30%|██▉       | 30.0M/100M [00:04<00:06, 11.7MB/s]
# ...

# %% [markdown]
# Downloading dataset from kaggle

# %% [markdown]
# Preprocessing dataset:
# Unzip dataset

# %%
import zipfile
with zipfile.ZipFile("dataset/task-1.zip",'r') as zip_ref:
    zip_ref.extractall("dataset/")
